# %%
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print sys.version
print "Pandas", pd.version.version
# Out:
# 2.7.9 |Anaconda 2.2.0 (x86_64)| (default, Dec 15 2014, 10:37:34)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas 0.15.2

# %%
df = pd.read_csv('../csv_files/raw_file.csv')

# %%
df
# Out:
#         Date  Miles     Time
# 0     8/2/14   1.70      NaN
# 1     8/3/14   1.40      NaN
# 2     8/4/14   2.10      NaN
# 3     8/6/14   2.38      NaN
# 4     8/7/14   2.30      NaN
# 5     8/8/14   3.40      NaN
# 6     8/9/14   2.50      NaN
# 7    8/10/14   3.36  0:28:37
# 8    8/11/14   1.67  0:13:07
# 9    8/12/14   1.42  0:10:35
# 10   8/13/14   2.35  0:17:25
# 11   8/14/14   0.90  0:06:16
# 12   8/14/14   0.90  0:06:16
# 13   8/15/14   1.78      NaN
# 14   8/16/14   0.65      NaN
# 15   8/17/14   1.34      NaN
# 16   8/18/14   0.65      NaN
# 17   8/19/14   1.37      NaN
# 18   8/19/14   1.37      NaN
# 19   8/20/14   1.37  0:09:33
# 20   8/21/14   1.37  0:09:24
# 21   8/22/14   1.37  0:09:05
# 22   8/23/14   1.34      NaN
# 23   8/24/14   3.00      NaN
# 24   8/25/14   1.37  0:08:55
# 25   8/25/14   1.34      NaN
# 26   8/26/14   1.37  0:10:30
# 27   8/27/14   2.50  0:25:00
# 28   8/29/14   5.00  0:43:27
# 29    9/2/14   2.00      NaN
# ..       ...    ...      ...
# ...
